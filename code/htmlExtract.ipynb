# %%
import pandas as pd
import os

# %%
### Convert files to HTML

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\isaldiviagonzatti\\OneDrive - Kiel Institut für Weltwirtschaft\\Documents\\General\\Ignacio'

# %%
data = 'data'
# Out:
# 'data\\pdf_ices_test\x08li.27.5b67.html'

# %%
htmltest = pd.read_html(os.path.join(data,'pdf_ices_test\bli.27.5b67.html'))

# %%
htmltest[6].columns= htmltest[6].iloc[0]
htmltest[6]['year']
# Out:
# 0   Year                                        ICES advice  \
# 0   Year                                        ICES advice
# 1   2003                               No direct fisheries^
# 2   2004                                          Biennial^
# 3   2005                               No direct fisheries^
# 4   2006                                          Biennial^
# 5   2007                                No direct fisheries
# 6   2008                                           Biennial
# 7   2009                                No direct fisheries
# 8   2010                                           Biennial
# 9   2011  No direct fishery and effort to limit bycatch....
# 10  2012                        No new advice, same as 2011
# 11  2013                         Average catch 2008 to 2011
# 12  2014                        No new advice, same as 2013
# 13  2015                                       MSY approach
# 14  2016                        No new advice, same as 2015
# ...
